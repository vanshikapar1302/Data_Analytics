# %%
import pandas as pd

# %%
info = {
    "Name": ["Rahul", "Harshita", "Shradha"],
    "CGPA": [9.5, 7.5, 8.5]
}
df = pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5

# %%
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1  Harshita   7.5
# 2   Shradha   8.5

# %%
list=pd.Series([1,2,3,4,5])
print(list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(list[0])
# Out:
# 1

# %%
list=pd.Series([1,2,3,4,5],index=(["Vanshika","Vansh","Shruti","Apoorva","Kashish"]))
print(list)
# Out:
# Vanshika    1
# Vansh       2
# Shruti      3
# Apoorva     4
# Kashish     5
# dtype: int64

# %%
list1=pd.Series([1,2,3,4,5])
list2=pd.Series([1,2,3,4,5])
print(list1+list2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
info = {
    "Name": ["Rahul", "Harshita", "Shradha"],
    "Age":[24,23,26],
    "CGPA": [9.5, 7.5, 8.5]
}
df = pd.DataFrame(info)
print(df)
# Out:
#        Name  Age  CGPA
# 0     Rahul   24   9.5
# 1  Harshita   23   7.5
# 2   Shradha   26   8.5

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'CGPA'], dtype='object')

# %%
data=[
    ["Vanshika", 8.1],
    ["Vansh", 8.5],
    ["Shruti", 8.9],
    ["Apoorva", 9.3],
    ["Kashish", 8.9]
]
df = pd.DataFrame(data, columns=["Name", "CGPA"])
print(df)
# Out:
#        Name  CGPA
# 0  Vanshika   8.1
# 1     Vansh   8.5
# 2    Shruti   8.9
# 3   Apoorva   9.3
# 4   Kashish   8.9

# %%
df
# Out:
#        Name  CGPA
# 0  Vanshika   8.1
# 1     Vansh   8.5
# 2    Shruti   8.9
# 3   Apoorva   9.3
# 4   Kashish   8.9

# %%
import numpy as np
np_array=np.array([[1,3,4],[7,1,5],[2,4,7]])
df = pd.DataFrame(np_array)
print(df)
# Out:
#    0  1  2
# 0  1  3  4
# 1  7  1  5
# 2  2  4  7

# %%
df
# Out:
#    0  1  2
# 0  1  3  4
# 1  7  1  5
# 2  2  4  7

# %%
data = [
    ["Vanshika", 9.1],
    ["Vansh", 8.5],
    ["Shruti", 8.9],
    ["Apoorva", 9.3],
    ["Kashish", 8.7]
]

dataframe = pd.DataFrame(data, columns=["Name", "CGPA"])


dataframe.to_json("students.json", orient="records", indent=4)
dataframe.to_csv("students.csv", index=False)

# %%
dataframe=pd.read_csv("students.csv")
print(dataframe)
# Out:
#        Name  CGPA
# 0  Vanshika   9.1
# 1     Vansh   8.5
# 2    Shruti   8.9
# 3   Apoorva   9.3
# 4   Kashish   8.7

# %%
dataframe=pd.read_json("students.json")
print(dataframe)
# Out:
#        Name  CGPA
# 0  Vanshika   9.1
# 1     Vansh   8.5
# 2    Shruti   8.9
# 3   Apoorva   9.3
# 4   Kashish   8.7

# %%
dataframe.tail(2)
# Out:
#       Name  CGPA
# 3  Apoorva   9.3
# 4  Kashish   8.7

# %%
dataframe.head(2)
# Out:
#        Name  CGPA
# 0  Vanshika   9.1
# 1     Vansh   8.5

# %%
dataframe.sample()
# Out:
#        Name  CGPA
# 0  Vanshika   9.1

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   CGPA    5 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 212.0+ bytes

# %%
dataframe.shape
# Out:
# (5, 2)

# %%
dataframe.describe()
# Out:
#            CGPA
# count  5.000000
# mean   8.900000
# std    0.316228
# min    8.500000
# 25%    8.700000
# 50%    8.900000
# 75%    9.100000
# max    9.300000

# %%
dataframe.columns
# Out:
# Index(['Name', 'CGPA'], dtype='object')

# %%
dataframe.nunique()
# Out:
# Name    5
# CGPA    5
# dtype: int64

# %%
df = pd.read_csv("st.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.read_csv("st.csv")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df = pd.read_csv("globalAirQuality.csv")
df

# %%
df["country"]

# %%
df[["city","aqi"]]

# %%
df.loc[0]
df.loc[0:6]
# Out:
#    0  1  2
# 0  1  3  4
# 1  7  1  5
# 2  2  4  7

# %%
df.iloc[0]
# Out:
# 0    1
# 1    3
# 2    4
# Name: 0, dtype: int64

# %%
df.loc[100:110,["city","aqi"]]

# %%
df.iloc[100:110,[4,5]]

# %%
df.at[0,"city"]

# %%
filter_data=df[(df["aqi"] > 100) & (df["temperature"] <30)]
print(filter_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 filter_data=df[(df["aqi"] > 100) & (df["temperature"] <30)]
#       2 print(filter_data)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'aqi'

# %%
filter_data=df[df["aqi"] > 100][["city","aqi"]]
print(filter_data)
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 6      New York  155
# 7      New York  115
# 8      New York  121
# ...         ...  ...
# 17991    Zurich  104
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [9721 rows x 2 columns]

# %%
filter_data=df[(df["aqi"] > 100) & (df["temperature"] <30)][["city","aqi"]]
print(filter_data)
filter_data.loc[3]
filter_data.iloc[3]
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 8      New York  121
# 12     New York  114
# 13     New York  124
# ...         ...  ...
# 17988    Zurich  122
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [7337 rows x 2 columns]
# city    New York
# aqi          114
# Name: 12, dtype: object

# %%
filtered_df = df.query("aqi > 100 and temperature < 30")
filtered_df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# 12     2025-11-05 06:25:17.554219      US  New York    40.713    -74.006
# 13     2025-11-05 07:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17988  2025-11-19 06:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
filtered_df = df.query("aqi > 100 and temperature < 30")[["city","aqi"]]
filtered_df
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 8      New York  121
# 12     New York  114
# 13     New York  124
# ...         ...  ...
# 17988    Zurich  122
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [7337 rows x 2 columns]

# %%
df=pd.read_csv("raw_data.csv")
df.isnull()
# Out:
#        id   name    age  country  gender  income
# 0   False  False  False    False   False   False
# 1   False  False  False    False   False   False
# 2   False  False   True    False   False   False
# 3   False  False   True    False   False   False
# 4   False  False  False    False   False    True
# 5   False  False  False    False   False   False
# 6   False   True  False    False   False   False
# 7   False  False  False     True   False   False
# 8   False  False  False    False   False   False
# 9   False  False   True    False   False   False
# 10  False  False  False    False    True   False

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df.isnull().sum()
# Out:
# id         0
# name       1
# age        3
# country    1
# gender     1
# income     1
# dtype: int64

# %%
df.dropna()
# Out:
#    id        name   age country  gender   income
# 0   1    John Doe  29.0     USA    Male  55000.0
# 1   1    John Doe  29.0     USA    Male  55000.0
# 5   5      Li Wei  27.0   China    Male  51000.0
# 8   8  Rachel Lee  29.0     USA  Female  62000.0

# %%
df.fillna(0)
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   0.0  Canada   Female  62000.0
# 3    3          Alex   0.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      0.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6             0  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0       0     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA        0  58000.0

# %%
age_mean = df["age"].mean()
print(age_mean)
df["age"] = df["age"].fillna(age_mean)
df
# Out:
# 32.75
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00     NaN     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
df["age"] = df["age"].ffill()
df
# Out:
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00   India     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
df["age"] = df["age"].bfill()
df
# Out:
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00   India     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
df2 = df.copy()
df2 = df2.fillna(0)
df2["age"] = df2["age"].astype("int64").copy()

print(df2.dtypes)
# Out:
# id           int64
# name        object
# age          int64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
df2
# Out:
#     id          name  age country   gender   income
# 0    1      John Doe   29     USA     Male  55000.0
# 1    1      John Doe   29     USA     Male  55000.0
# 2    2    Jane Smith   32  Canada   Female  62000.0
# 3    3          Alex   32     USA  Unknown  47000.0
# 4    4  Maria Garcia   34   Spain   Female      0.0
# 5    5        Li Wei   27   China     Male  51000.0
# 6    6             0   45   India   Female  73000.0
# 7    7    Ahmed Khan   38   India     Male  68000.0
# 8    8    Rachel Lee   29     USA   Female  62000.0
# 9    9   Carlos Ruiz   32  Mexico     Male  45000.0
# 10  10   Emily Davis   31     USA        0  58000.0

# %%
date_str = pd.Series([pd.to_datetime("2026-12-31")])
type(date_str.dtypes)
# Out:
# numpy.dtypes.DateTime64DType

# %%
aqi_data = pd.read_csv("globalAirQuality.csv")
aqi_data["timestamp"] = pd.to_datetime(aqi_data["timestamp"])
aqi_data["timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %%
# !pip install requests

# %%
# !pip install requests
